# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

xs = (np.random.rand(5) * 100).round()
ys = np.random.rand(5) * 100
xs = np.sort(xs)
print("xs: ", xs)
print("ys: ", ys)

plt.plot(xs, ys)
plt.show()
# Out:
# xs:  [13. 28. 34. 73. 99.]
# ys:  [14.56674334 77.19389567 19.77442674 23.77151055 15.94040227]

# %%
a_s = [[1,22,3,4],[1,2,3,5]]
#print(a_s.shapes)
b_s = [[11,12,12,14],[1,2,3,4]]
plt.plot(a_s, b_s)
plt.show()

# %%
x = np.arange(0, 5, 0.1)
y = np.sin(x)
plt.plot(x, y)

# %%
from lesson.dataset import get_beans
plt.scatter(xs, ys)
plt.show()
