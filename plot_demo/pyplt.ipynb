# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

xs = (np.random.rand(5) * 100).round()
ys = np.random.rand(5) * 100
xs = np.sort(xs)
print("xs: ", xs)
print("ys: ", ys)

plt.plot(xs, ys)
plt.show()
# Out:
# xs:  [10. 15. 26. 42. 87.]
# ys:  [ 4.98035122 83.62855543 26.99212914 62.60495625 15.24088745]

# %%
a_s = [[1,22,3,4],[1,2,3,5]]
#print(a_s.shapes)
b_s = [[11,12,12,14],[1,2,3,4]]
plt.plot(a_s, b_s)
plt.show()

# %%
x = np.arange(0, 5, 0.1)
y = np.sin(x)
plt.plot(x, y)

# %%
from lesson.dataset import get_beans

xs, ys = get_beans(100)
plt.scatter(xs, ys)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/w1/f3yh3hh57qs7ymg2bm22vd340000gn/T/ipykernel_12343/1640522813.py in <module>
# ----> 1 from lesson.dataset import get_beans
#       2
#       3 xs, ys = get_beans(100)
#       4 plt.scatter(xs, ys)
#       5 plt.show()
#
# ModuleNotFoundError: No module named 'lesson'
