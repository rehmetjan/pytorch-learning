# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

xs = (np.random.rand(5) * 100).round()
ys = np.random.rand(5) * 100
xs = np.sort(xs)
print("xs: ", xs)
print("ys: ", ys)

plt.plot(xs, ys)
plt.show()
# Out:
# xs:  [ 8. 11. 27. 43. 73.]
# ys:  [17.83004363 32.71024864 77.5976113  84.08122749 20.57377867]

# %%
a_s = [[1,22,3,4],[1,2,3,5]]
#print(a_s.shapes)
b_s = [[11,12,12,14],[1,2,3,4]]
plt.plot(a_s, b_s)
plt.show()

# %%
x = np.arange(0, 5, 0.1)
y = np.sin(x)
plt.plot(x, y)
